# %% [markdown]
# ### Starting a new project!
#
# #### I am going to use the same data set that I have used for a previous project to analyze building permits this time.
#
# #### I'm going to focus on costs of different types of houring units? Not sure yet. May try to make a display where you can change what you're viewing.
#
# link to data --> https://data.seattle.gov/Built-Environment/Building-Permits/76t5-zqzr/about_data

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as pyplot

import shapely

pd.set_option('display.max_columns', None) ### This line makes all the columns display, rather than ellipses shorten

# %%
date_columns = ['AppliedDate','IssuedDate', 'ExpiresDate', 'CompletedDate']

#building_permit_gdf = gpd.read_file("C:/Users/aaron/Fun Mapping Work/Data/Seattle_Building_Permit_Data/Building_Permits_20251209.csv")
#building_permit_gdf = pd.read_csv("C:/Users/aaron/Fun Mapping Work/Data/Seattle_Building_Permit_Data/Building_Permits_20251209.csv", dtype = {'EstProjectCost':float})
building_permit_df = pd.read_csv("C:/Users/aaron/Fun Mapping Work/Data/Seattle_Building_Permit_Data/Building_Permits_20251209.csv",parse_dates = date_columns)
#building_permit_df = pd.read_csv("C:/Users/aaron/Fun Mapping Work/Data/Seattle_Building_Permit_Data/Building_Permits_20251209.csv")
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_46840\4133205410.py:5: DtypeWarning: Columns (25,26,27,28,30,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   building_permit_df = pd.read_csv("C:/Users/aaron/Fun Mapping Work/Data/Seattle_Building_Permit_Data/Building_Permits_20251209.csv",parse_dates = date_columns)

# %%
## cast EstProjectCost as an int

#building_permit_df['EstProjectCost'] = building_permit_df['EstProjectCost'].str.extract('(\d+)', expand=False)
#building_permit_df['EstProjectCost'] = building_permit_df['EstProjectCost'].astype(int)

building_permit_df['EstProjectCost'] = building_permit_df['EstProjectCost'].str.replace(',', '')
building_permit_df['EstProjectCost'] = pd.to_numeric(building_permit_df['EstProjectCost'], errors='coerce')
building_permit_df = building_permit_df.dropna(subset=['EstProjectCost'])
building_permit_df['EstProjectCost'] = building_permit_df['EstProjectCost'].astype(int)

# %%
building_permit_df.head()
# Out:
#       PermitNum           PermitClass PermitClassMapped  \
# 472  3026027-EX           Multifamily       Residential
# 498  6062075-CN  Single Family/Duplex       Residential
# 499  6062129-CN  Single Family/Duplex       Residential
# 500  6062295-CN  Single Family/Duplex       Residential
# 501  6062303-CN            Commercial   Non-Residential
#
#                                       PermitTypeMapped  \
# 472  ECA and Shoreline Exemption/Street Improvement...
# 498                                           Building
# 499                                           Building
# 500                                           Building
# 501                                           Building
#
#                    PermitTypeDesc  \
# 472  Street Improvement Exception
# 498           Addition/Alteration
# 499           Addition/Alteration
# 500           Addition/Alteration
# 501           Addition/Alteration
#
#                                            Description  HousingUnits  \
# 472  Exception/Exemption Request for: Land Use Appl...             0
# 498  Closed as Incomplete - Expired Permit    SFR D...             0
# 499  Construct porch along side of existing single-...             0
# 500  Closed as Incomplete - Expired Permit    Const...             0
# 501  Closed as Incomplete - Expired Permit    RENOV...             0
#
#      HousingUnitsRemoved  HousingUnitsAdded  EstProjectCost AppliedDate  \
# 472                  NaN                NaN               0         NaT
# 498                  0.0                0.0           47375  2006-04-06
# 499                  NaN                NaN            4460  2006-08-08
# 500                  NaN                NaN            5160  2006-05-26
# 501                  0.0                0.0            3306  2006-09-22
#
#     IssuedDate ExpiresDate CompletedDate StatusCurrent  RelatedMup  \
# 472        NaT         NaT           NaT     Completed  3026027-LU
# 498 2006-04-14  2007-10-14           NaT     Completed         NaN
# 499 2006-08-08  2008-02-08    2006-11-27     Completed         NaN
# 500 2006-05-26  2007-11-26           NaT     Completed         NaN
# 501 2006-12-07  2008-06-07           NaT     Completed         NaN
#
#      OriginalAddress1 OriginalCity OriginalState  OriginalZip  \
# 472   3008 16TH AVE W      SEATTLE            WA      98119.0
# 498     415 W HOWE ST      SEATTLE            WA      98119.0
# 499  4667 S WILLOW ST      SEATTLE            WA      98118.0
# 500  3891 W CRAMER ST      SEATTLE            WA      98199.0
# 501  3411 S ALASKA ST      SEATTLE            WA      98118.0
#
#     ContractorCompanyName                                               Link  \
# 472                   NaN  https://services.seattle.gov/portal/customize/...
# 498                   NaN  https://services.seattle.gov/portal/customize/...
# 499                   NaN  https://services.seattle.gov/portal/customize/...
# 500                   NaN  https://services.seattle.gov/portal/customize/...
# 501                   NaN  https://services.seattle.gov/portal/customize/...
#
#       Latitude   Longitude                     Location1 TotalDaysPlanReview  \
# 472  47.646889 -122.377127  (47.64688862, -122.37712742)                 NaN
# 498  47.635770 -122.363105  (47.63576954, -122.36310456)                 NaN
# 499  47.540516 -122.272480  (47.54051557, -122.27247985)                 NaN
# 500  47.667627 -122.408581  (47.66762736, -122.40858111)                 NaN
# 501  47.560289 -122.289159  (47.56028939, -122.28915912)                 NaN
#
#     DaysInitialPlanReview DaysPlanReviewCity DaysOutCorrections  \
# 472                   NaN                NaN                  0
# 498                   NaN                NaN                  0
# 499                   NaN                NaN                  0
# 500                   NaN                NaN                  0
# 501                   NaN                NaN                  0
#
#      NumberReviewCycles InitialReviewCompleteDate PlanReviewCompleteDate  \
# 472                 0.0                       NaN                    NaN
# 498                 0.0                       NaN                    NaN
# 499                 0.0                       NaN                    NaN
# 500                 0.0                       NaN                    NaN
# 501                 0.0                       NaN                    NaN
#
#     DaysIssuePermitCity ReadyToIssueDate Zoning DwellingUnitType  \
# 472                 NaN              NaN    NaN              NaN
# 498                 NaN              NaN    NaN              NaN
# 499                 NaN              NaN    NaN              NaN
# 500                 NaN              NaN    NaN              NaN
# 501                 NaN              NaN    NaN              NaN
#
#      StandardPlan  DependentBuilding ParentPermitNum        HousingCategory
# 472           NaN                  0             NaN                    NaN
# 498           NaN                  0             NaN  Single-Family Add/Alt
# 499           NaN                  0             NaN  Single-Family Add/Alt
# 500           NaN                  0             NaN  Single-Family Add/Alt
# 501           NaN                  0             NaN     Commercial Add/Alt

# %%
building_permit_df.HousingCategory.unique()
# Out:
# array([nan, 'Single-Family Add/Alt', 'Commercial Add/Alt',
#        'Middle Housing', 'Housing - Other', 'Multifamily - Other',
#        'Pre-Approved DADU Plans'], dtype=object)

# %%
building_permit_df = building_permit_df.sort_values(by='EstProjectCost', ascending=False)

# %%
building_permit_df.info() ## shows the type of all columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151057 entries, 164709 to 123117
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   PermitNum                  151057 non-null  object
#  1   PermitClass                151029 non-null  object
#  2   PermitClassMapped          151029 non-null  object
#  3   PermitTypeMapped           151057 non-null  object
#  4   PermitTypeDesc             144618 non-null  object
#  5   Description                151018 non-null  object
#  6   HousingUnits               151057 non-null  int64
#  7   HousingUnitsRemoved        80963 non-null   float64
#  8   HousingUnitsAdded          80963 non-null   float64
#  9   EstProjectCost             151057 non-null  int64
#  10  AppliedDate                129925 non-null  datetime64[ns]
#  11  IssuedDate                 123515 non-null  datetime64[ns]
#  12  ExpiresDate                123595 non-null  datetime64[ns]
#  13  CompletedDate              93004 non-null   datetime64[ns]
#  14  StatusCurrent              151057 non-null  object
#  15  RelatedMup                 10772 non-null   object
#  16  OriginalAddress1           150769 non-null  object
#  17  OriginalCity               143309 non-null  object
#  18  OriginalState              143447 non-null  object
#  19  OriginalZip                142376 non-null  float64
#  20  ContractorCompanyName      21347 non-null   object
#  21  Link                       151057 non-null  object
#  22  Latitude                   150684 non-null  float64
#  23  Longitude                  150684 non-null  float64
#  24  Location1                  150684 non-null  object
#  25  TotalDaysPlanReview        29529 non-null   object
#  26  DaysInitialPlanReview      29921 non-null   object
#  27  DaysPlanReviewCity         29529 non-null   object
#  28  DaysOutCorrections         142828 non-null  object
#  29  NumberReviewCycles         142828 non-null  float64
#  30  InitialReviewCompleteDate  29974 non-null   object
#  31  PlanReviewCompleteDate     29585 non-null   object
#  32  DaysIssuePermitCity        22593 non-null   object
#  33  ReadyToIssueDate           49375 non-null   object
#  34  Zoning                     56619 non-null   object
#  35  DwellingUnitType           57791 non-null   object
#  36  StandardPlan               57848 non-null   float64
#  37  DependentBuilding          151057 non-null  int64
#  38  ParentPermitNum            34813 non-null   object
#  39  HousingCategory            108222 non-null  object
# dtypes: datetime64[ns](4), float64(7), int64(3), object(26)
# memory usage: 47.3+ MB

# %%
building_permit_df.head(10)
# Out:
#          PermitNum    PermitClass PermitClassMapped  \
# 164709  6973064-DM    Multifamily       Residential
# 156067  6973063-CN    Multifamily       Residential
# 182539  7103217-CN     Commercial   Non-Residential
# 146663  6830099-CN  Institutional   Non-Residential
# 131542  6781193-CN    Multifamily       Residential
# 136383  6781194-DM    Multifamily       Residential
# 162296  7018897-CN     Industrial   Non-Residential
# 171642  6879594-EX  Institutional   Non-Residential
# 136079  6694765-PH     Commercial   Non-Residential
# 120303  6706025-PH     Commercial   Non-Residential
#
#                                          PermitTypeMapped  \
# 164709                                         Demolition
# 156067                                           Building
# 182539                                           Building
# 146663                                           Building
# 131542                                           Building
# 136383                                         Demolition
# 162296                                           Building
# 171642  ECA and Shoreline Exemption/Street Improvement...
# 136079                                           Building
# 120303                                           Building
#
#                     PermitTypeDesc  \
# 164709                         NaN
# 156067                         New
# 182539         Addition/Alteration
# 146663                         New
# 131542                         New
# 136383                         NaN
# 162296                         New
# 171642  Shoreline Permit Exemption
# 136079         Addition/Alteration
# 120303                         New
#
#                                               Description  HousingUnits  \
# 164709  Building a new 5 story over a 2 story base str...            52
# 156067  Building a new 5 story over a 2 story base str...            52
# 182539  [LAND USE STATEMENT] Construct alterations to ...             0
# 146663  Master Use Permit to Construct a 4 Story  175 ...             0
# 131542                                                  :             0
# 136383                                                  :             0
# 162296  Expansion of existing Elliott West Wet Weather...             0
# 171642  Geotechnical investigation for Portage Bay Bri...             0
# 136079  Phased Project:  Substantial alterations for r...             0
# 120303  Phased permit:  Construction of a residential ...           891
#
#         HousingUnitsRemoved  HousingUnitsAdded  EstProjectCost AppliedDate  \
# 164709                  0.0               52.0     25000000000         NaT
# 156067                  0.0               52.0     25000000000         NaT
# 182539                  NaN                NaN      3320000555         NaT
# 146663                  NaN                NaN      1443000000         NaT
# 131542                  NaN                NaN      1000000000         NaT
# 136383                  NaN                NaN      1000000000         NaT
# 162296                  NaN                NaN       796000000         NaT
# 171642                  NaN                NaN       500000000         NaT
# 136079                  0.0                0.0       458767965  2018-11-06
# 120303                  0.0              891.0       370600000  2020-06-09
#
#        IssuedDate ExpiresDate CompletedDate              StatusCurrent  \
# 164709        NaT         NaT           NaT  Additional Info Requested
# 156067        NaT         NaT           NaT  Additional Info Requested
# 182539        NaT         NaT           NaT                  Scheduled
# 146663        NaT         NaT           NaT  Additional Info Requested
# 131542        NaT         NaT           NaT                  Withdrawn
# 136383        NaT         NaT           NaT                  Withdrawn
# 162296        NaT         NaT           NaT  Additional Info Requested
# 171642        NaT         NaT           NaT                  Completed
# 136079 2019-08-05  2022-08-05    2022-04-01                  Completed
# 120303 2021-11-29  2026-05-29           NaT                     Issued
#
#                     RelatedMup        OriginalAddress1 OriginalCity  \
# 164709                     NaN  5718 M L KING JR WAY S      SEATTLE
# 156067              3041031-LU  5718 M L KING JR WAY S      SEATTLE
# 182539                     NaN       419 RAINIER AVE S          NaN
# 146663              3037864-LU  4800 Sand Point WAY NE          NaN
# 131542                     NaN                     NaN          NaN
# 136383                     NaN                     NaN          NaN
# 162296                     NaN       531 ELLIOTT AVE W      SEATTLE
# 171642                     NaN      2548 B BOYER AVE E      SEATTLE
# 136079  3032552-LU, 3032560-LU           334 1ST AVE N      SEATTLE
# 120303              3020315-LU            2350 6TH AVE      SEATTLE
#
#        OriginalState  OriginalZip ContractorCompanyName  \
# 164709            WA      98118.0                   NaN
# 156067            WA      98118.0                   NaN
# 182539           NaN          NaN                   NaN
# 146663           NaN          NaN                   NaN
# 131542           NaN          NaN                   NaN
# 136383           NaN          NaN                   NaN
# 162296            WA      98119.0                   NaN
# 171642            WA      98102.0                   NaN
# 136079            WA      98109.0                   NaN
# 120303            WA      98121.0                   NaN
#
#                                                      Link   Latitude  \
# 164709  https://services.seattle.gov/portal/customize/...  47.550476
# 156067  https://services.seattle.gov/portal/customize/...  47.550476
# 182539  https://services.seattle.gov/portal/customize/...  47.598492
# 146663  https://services.seattle.gov/portal/customize/...  47.662319
# 131542  https://services.seattle.gov/portal/customize/...        NaN
# 136383  https://services.seattle.gov/portal/customize/...        NaN
# 162296  https://services.seattle.gov/portal/customize/...  47.623790
# 171642  https://services.seattle.gov/portal/customize/...  47.642884
# 136079  https://services.seattle.gov/portal/customize/...  47.622085
# 120303  https://services.seattle.gov/portal/customize/...  47.617319
#
#          Longitude                     Location1 TotalDaysPlanReview  \
# 164709 -122.287261  (47.55047631, -122.28726127)                 NaN
# 156067 -122.287261  (47.55047631, -122.28726127)                 NaN
# 182539 -122.313934  (47.59849246, -122.31393428)                 NaN
# 146663 -122.281473   (47.66231885, -122.2814725)                 NaN
# 131542         NaN                           NaN                 NaN
# 136383         NaN                           NaN                 NaN
# 162296 -122.365438  (47.62379047, -122.36543821)                 NaN
# 171642 -122.315843  (47.64288431, -122.31584285)                 NaN
# 136079 -122.353996  (47.62208508, -122.35399633)                 NaN
# 120303 -122.342747  (47.61731883, -122.34274681)                 NaN
#
#        DaysInitialPlanReview DaysPlanReviewCity DaysOutCorrections  \
# 164709                   NaN                NaN                  0
# 156067                   NaN                NaN                  0
# 182539                   NaN                NaN                  0
# 146663                   NaN                NaN                  0
# 131542                   NaN                NaN                NaN
# 136383                   NaN                NaN                NaN
# 162296                   NaN                NaN                  0
# 171642                   NaN                NaN                  0
# 136079                   132                NaN                 46
# 120303                   NaN                NaN                  0
#
#         NumberReviewCycles InitialReviewCompleteDate PlanReviewCompleteDate  \
# 164709                 0.0                       NaN                    NaN
# 156067                 0.0                       NaN                    NaN
# 182539                 0.0                       NaN                    NaN
# 146663                 0.0                       NaN                    NaN
# 131542                 NaN                       NaN                    NaN
# 136383                 NaN                       NaN                    NaN
# 162296                 0.0                       NaN                    NaN
# 171642                 0.0                       NaN                    NaN
# 136079                 3.0   2019 Mar 18 12:00:00 AM                    NaN
# 120303                 0.0                       NaN                    NaN
#
#        DaysIssuePermitCity ReadyToIssueDate Zoning DwellingUnitType  \
# 164709                 NaN              NaN    NaN              NaN
# 156067                 NaN              NaN    NaN              NaN
# 182539                 NaN              NaN    NaN              NaN
# 146663                 NaN              NaN    NaN              NaN
# 131542                 NaN              NaN    NaN              NaN
# 136383                 NaN              NaN    NaN              NaN
# 162296                 NaN              NaN    NaN              NaN
# 171642                 NaN              NaN    NaN              NaN
# 136079                 NaN              NaN    NaN       Commercial
# 120303                 NaN              NaN    DMC        Apartment
#
#         StandardPlan  DependentBuilding         ParentPermitNum  \
# 164709           NaN                  0                     NaN
# 156067           NaN                  0                     NaN
# 182539           NaN                  0                     NaN
# 146663           NaN                  0                     NaN
# 131542           NaN                  0                     NaN
# 136383           NaN                  0                     NaN
# 162296           NaN                  0                     NaN
# 171642           NaN                  0                     NaN
# 136079           0.0                  0  3032552-LU, 3032560-LU
# 120303           0.0                  0                     NaN
#
#            HousingCategory
# 164709                 NaN
# 156067                 NaN
# 182539  Commercial Add/Alt
# 146663                 NaN
# 131542                 NaN
# 136383                 NaN
# 162296                 NaN
# 171642                 NaN
# 136079  Commercial Add/Alt
# 120303                 NaN

# %%
max(building_permit_df.EstProjectCost)
# Out:
# 25000000000
